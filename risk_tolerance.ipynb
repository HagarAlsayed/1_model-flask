# %% [markdown]
# 1. IMPLEMENT LIBRARY

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.linear_model import LinearRegression,SGDRegressor,Lasso,ElasticNet,Ridge
from sklearn.model_selection import train_test_split,cross_val_score,KFold,GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,RandomForestRegressor,GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.metrics import confusion_matrix,f1_score
import pickle , joblib

# %% [markdown]
# 2. PREPARE DATA

# %%
df =pd.read_csv("InputData.csv")
df
# Out:
#       Unnamed: 0  AGE07  EDCL07  MARRIED07  KIDS07  LIFECL07  OCCAT107  \
# 0              0     47       2          1       0         2         1
# 1              1     47       2          1       0         2         1
# 2              2     47       2          1       0         2         1
# 3              3     47       2          1       0         2         1
# 4              4     47       2          1       0         2         1
# ...          ...    ...     ...        ...     ...       ...       ...
# 4805       19280     50       4          2       0         1         2
# 4806       19281     50       4          2       0         1         2
# 4807       19282     50       4          2       0         1         2
# 4808       19283     50       4          2       0         1         2
# 4809       19284     50       4          2       0         1         2
#
#           INCOME07  RISK07  WSAVED07  SPENDMOR07    NETWORTH07  TrueRiskTol
# 0     56443.744181       3         1           5  352641.71130     6.947439
# 1     56443.744181       3         1           5  340525.21881     6.223158
# 2     56443.744181       3         1           5  348696.08426     6.676709
# 3     56443.744181       3         1           5  351802.87720     6.286854
# 4     56443.744181       3         1           5  358958.85696     6.177016
# ...            ...     ...       ...         ...           ...          ...
# 4805  78808.246592       2         2           5  653876.35532     5.978830
# 4806  78808.246592       2         2           5  655843.99086     5.941754
# 4807  77743.270286       2         2           5  654911.95297     5.903461
# 4808  77743.270286       2         2           5  654911.95297     5.903461
# 4809  77743.270286       2         2           5  655947.55062     5.903461
#
# [4810 rows x 13 columns]

# %%
df.rename(columns={"Unnamed: 0":"id" , "AGE07":"age" , "EDCL07":"education_level" ,"MARRIED07":"married_state" , "KIDS07":"no_of_kids" ,
                   "LIFECL07":"life_statge" , "OCCAT107":"occupational_category" , "INCOME07":"income" , "RISK07":"risk", 
                   "WSAVED07":"wealth_saved" , "SPENDMOR07":"spend_amount" , "NETWORTH07":"net_worth" , "TrueRiskTol":"risk_tol"} ,inplace=True)

# %%
df
# Out:
#          id  age  education_level  married_state  no_of_kids  life_statge  \
# 0         0   47                2              1           0            2
# 1         1   47                2              1           0            2
# 2         2   47                2              1           0            2
# 3         3   47                2              1           0            2
# 4         4   47                2              1           0            2
# ...     ...  ...              ...            ...         ...          ...
# 4805  19280   50                4              2           0            1
# 4806  19281   50                4              2           0            1
# 4807  19282   50                4              2           0            1
# 4808  19283   50                4              2           0            1
# 4809  19284   50                4              2           0            1
#
#       occupational_category        income  risk  wealth_saved  spend_amount  \
# 0                         1  56443.744181     3             1             5
# 1                         1  56443.744181     3             1             5
# 2                         1  56443.744181     3             1             5
# 3                         1  56443.744181     3             1             5
# 4                         1  56443.744181     3             1             5
# ...                     ...           ...   ...           ...           ...
# 4805                      2  78808.246592     2             2             5
# 4806                      2  78808.246592     2             2             5
# 4807                      2  77743.270286     2             2             5
# 4808                      2  77743.270286     2             2             5
# 4809                      2  77743.270286     2             2             5
#
#          net_worth  risk_tol
# 0     352641.71130  6.947439
# 1     340525.21881  6.223158
# 2     348696.08426  6.676709
# 3     351802.87720  6.286854
# 4     358958.85696  6.177016
# ...            ...       ...
# 4805  653876.35532  5.978830
# 4806  655843.99086  5.941754
# 4807  654911.95297  5.903461
# 4808  654911.95297  5.903461
# 4809  655947.55062  5.903461
#
# [4810 rows x 13 columns]

# %% [markdown]
# 3. DATA WRANGLING

# %% [markdown]
# ARE THERE MISSING VALUES?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4810 entries, 0 to 4809
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     4810 non-null   int64
#  1   age                    4810 non-null   int64
#  2   education_level        4810 non-null   int64
#  3   married_state          4810 non-null   int64
#  4   no_of_kids             4810 non-null   int64
#  5   life_statge            4810 non-null   int64
#  6   occupational_category  4810 non-null   int64
#  7   income                 4810 non-null   float64
#  8   risk                   4810 non-null   int64
#  9   wealth_saved           4810 non-null   int64
#  10  spend_amount           4810 non-null   int64
#  11  net_worth              4810 non-null   float64
#  12  risk_tol               4810 non-null   float64
# dtypes: float64(3), int64(10)
# memory usage: 488.6 KB

# %%
df.describe()
# Out:
#                  id          age  education_level  married_state   no_of_kids  \
# count   4810.000000  4810.000000      4810.000000    4810.000000  4810.000000
# mean    9915.072349    55.513721         3.311850       1.207277     0.769647
# std     5662.856824    13.512250         0.960893       0.405397     1.094113
# min        0.000000    22.000000         1.000000       1.000000     0.000000
# 25%     4927.250000    45.250000         2.000000       1.000000     0.000000
# 50%    10175.500000    56.000000         4.000000       1.000000     0.000000
# 75%    14831.750000    65.000000         4.000000       1.000000     1.000000
# max    19284.000000    95.000000         4.000000       2.000000     7.000000
#
#        life_statge  occupational_category        income         risk  \
# count   4810.00000            4810.000000  4.810000e+03  4810.000000
# mean       4.11185               1.708732  1.175117e+06     2.833056
# std        1.50923               0.829500  4.990972e+06     0.808942
# min        1.00000               1.000000  0.000000e+00     1.000000
# 25%        3.00000               1.000000  6.496355e+04     2.000000
# 50%        5.00000               1.000000  1.160824e+05     3.000000
# 75%        5.00000               2.000000  3.237528e+05     3.000000
# max        6.00000               4.000000  6.838213e+07     4.000000
#
#        wealth_saved  spend_amount     net_worth     risk_tol
# count   4810.000000   4810.000000  4.810000e+03  4810.000000
# mean       2.616424      3.530146  1.870233e+07    10.778694
# std        0.674415      1.306774  8.159961e+07    15.853115
# min        1.000000      1.000000 -5.633237e+06     0.450112
# 25%        2.000000      2.000000  2.139545e+05     1.032562
# 50%        3.000000      4.000000  7.159087e+05     4.047974
# 75%        3.000000      5.000000  4.333743e+06    13.620327
# max        3.000000      5.000000  1.451956e+09    98.604330

# %% [markdown]
# DROP THE UNUSEFULL FEATURE

# %%
df.drop(["id","net_worth" ,"spend_amount" ,"wealth_saved"]  ,axis=1, inplace=True)

# %% [markdown]
# income in data for year not month

# %%
df["income"] = df["income"]/12

# %%
df
# Out:
#       age  education_level  married_state  no_of_kids  life_statge  \
# 0      47                2              1           0            2
# 1      47                2              1           0            2
# 2      47                2              1           0            2
# 3      47                2              1           0            2
# 4      47                2              1           0            2
# ...   ...              ...            ...         ...          ...
# 4805   50                4              2           0            1
# 4806   50                4              2           0            1
# 4807   50                4              2           0            1
# 4808   50                4              2           0            1
# 4809   50                4              2           0            1
#
#       occupational_category       income  risk  risk_tol
# 0                         1  4703.645348     3  6.947439
# 1                         1  4703.645348     3  6.223158
# 2                         1  4703.645348     3  6.676709
# 3                         1  4703.645348     3  6.286854
# 4                         1  4703.645348     3  6.177016
# ...                     ...          ...   ...       ...
# 4805                      2  6567.353883     2  5.978830
# 4806                      2  6567.353883     2  5.941754
# 4807                      2  6478.605857     2  5.903461
# 4808                      2  6478.605857     2  5.903461
# 4809                      2  6478.605857     2  5.903461
#
# [4810 rows x 9 columns]

# %% [markdown]
# UNDERSTANDING DATA BY VISULAIZATION

# %%
sns.scatterplot(x="age" , y="risk_tol" , data= df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='risk_tol'>

# %% [markdown]
# yes, as we see the younger people can endures high risk

# %%
sns.barplot(x="education_level" , y="risk_tol" , data= df)
# Out:
# <AxesSubplot:xlabel='education_level', ylabel='risk_tol'>

# %%
df["education_level"].value_counts()
# Out:
# 4    2964
# 2     984
# 3     622
# 1     240
# Name: education_level, dtype: int64

# %%
sns.barplot(df["education_level"] , df["income"])
# Out:
# e:\anaconda install\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='education_level', ylabel='income'>

# %% [markdown]
# level 4 the biggest income ?? how it appears as the less risk :)

# %%
sns.barplot(df["education_level"] , df["age"])
# Out:
# e:\anaconda install\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='education_level', ylabel='age'>

# %%
sns.barplot(x="married_state" , y="risk_tol" , data= df)
# Out:
# <AxesSubplot:xlabel='married_state', ylabel='risk_tol'>

# %% [markdown]
# 1 represents married state ,but is this true the married people endures high risk?

# %%
sns.barplot(x="married_state" , y="income" , data= df)
# Out:
# <AxesSubplot:xlabel='married_state', ylabel='income'>

# %%
sns.barplot(x="no_of_kids" , y="risk_tol" , data= df)
# Out:
# <AxesSubplot:xlabel='no_of_kids', ylabel='risk_tol'>

# %% [markdown]
# if the no.of.kids increase the risk tol must decrease. is this true always?

# %%
sns.scatterplot(y="no_of_kids" , x="married_state" , data= df)
# Out:
# <AxesSubplot:xlabel='married_state', ylabel='no_of_kids'>

# %%
df[df["married_state"]==2].nunique()
# Out:
# age                       60
# education_level            4
# married_state              1
# no_of_kids                 6
# life_statge                4
# occupational_category      4
# income                   230
# risk                       4
# risk_tol                 793
# dtype: int64

# %% [markdown]
# how?????? unmarried has kids it may be Divorced!?

# %%
sns.barplot(x="life_statge" , y="risk_tol" , data= df)
# Out:
# <AxesSubplot:xlabel='life_statge', ylabel='risk_tol'>

# %% [markdown]
# as see at level 5,6 the older people can't endures high risk

# %%
sns.barplot(x="life_statge" , y="age" , data= df)
# Out:
# <AxesSubplot:xlabel='life_statge', ylabel='age'>

# %% [markdown]
# i make sure that is life statge represent the Ages :))

# %%
sns.barplot(x="occupational_category" , y="risk_tol" , data= df)
# Out:
# <AxesSubplot:xlabel='occupational_category', ylabel='risk_tol'>

# %% [markdown]
# 4 represents unemployed , how they can endures high risk??

# %%
sns.barplot(df["occupational_category"] ,df["income"])
# Out:
# e:\anaconda install\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='occupational_category', ylabel='income'>

# %% [markdown]
# level 4 (unemployed) their income is so small , but this still not true for them to endures high risk

# %%
sns.scatterplot(x="income" , y="risk_tol" , data= df)
# Out:
# <AxesSubplot:xlabel='income', ylabel='risk_tol'>

# %%
sns.barplot(x="risk" , y="risk_tol" , data= df)
# Out:
# <AxesSubplot:xlabel='risk', ylabel='risk_tol'>

# %%
df["risk"].value_counts()
# Out:
# 3    2348
# 2    1223
# 4     966
# 1     273
# Name: risk, dtype: int64

# %%
plt.figure(figsize=((16,5)))
sns.heatmap(df.corr() , annot=True)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4810 entries, 0 to 4809
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age                    4810 non-null   int64
#  1   education_level        4810 non-null   int64
#  2   married_state          4810 non-null   int64
#  3   no_of_kids             4810 non-null   int64
#  4   life_statge            4810 non-null   int64
#  5   occupational_category  4810 non-null   int64
#  6   income                 4810 non-null   float64
#  7   risk                   4810 non-null   int64
#  8   risk_tol               4810 non-null   float64
# dtypes: float64(2), int64(7)
# memory usage: 338.3 KB

# %% [markdown]
# FEATURE ENGINEERING

# %%
sns.barplot(df["education_level"] , df["risk_tol"])
# Out:
# e:\anaconda install\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='education_level', ylabel='risk_tol'>

# %%
plt.figure(figsize=((20,5)))
sns.barplot(df["age"].unique(),df["age"].value_counts())
# Out:
# e:\anaconda install\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:ylabel='age'>

# %%
df["education_level"].value_counts()
# Out:
# 4    2964
# 2     984
# 3     622
# 1     240
# Name: education_level, dtype: int64

# %%
data=[]
for i in range (len(df["education_level"])):
    if df["education_level"][i] == 4 and df["age"][i]>=60 : data.append(1) 
    else : data.append(0)

# %%
df.insert(8 ,"eager" , data)

# %%
sns.barplot(df["eager"] , df["risk_tol"])
# Out:
# e:\anaconda install\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='eager', ylabel='risk_tol'>

# %%
df["occupational_category"].value_counts()
# Out:
# 1    2511
# 2    1237
# 3    1014
# 4      48
# Name: occupational_category, dtype: int64

# %%
df.groupby(["occupational_category" , "age"]).age.agg(['sum'])
# Out:
#                            sum
# occupational_category age
# 1                     22    22
#                       23   230
#                       25    75
#                       26   390
#                       27   405
# ...                        ...
# 4                     53   265
#                       55   385
#                       56   168
#                       57   171
#                       63   567
#
# [173 rows x 1 columns]

# %%
df["married_state"].value_counts()
# Out:
# 1    3813
# 2     997
# Name: married_state, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4810 entries, 0 to 4809
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   age                    4810 non-null   int64
#  1   education_level        4810 non-null   int64
#  2   married_state          4810 non-null   int64
#  3   no_of_kids             4810 non-null   int64
#  4   life_statge            4810 non-null   int64
#  5   occupational_category  4810 non-null   int64
#  6   income                 4810 non-null   float64
#  7   risk                   4810 non-null   int64
#  8   eager                  4810 non-null   int64
#  9   risk_tol               4810 non-null   float64
# dtypes: float64(2), int64(8)
# memory usage: 375.9 KB

# %% [markdown]
# 4. Evaluate Algorithms and Models

# %%
x = df.drop(["risk_tol"] , axis=1)
y = df["risk_tol"]

# %%
#scaler  = StandardScaler()
#x_scale = scaler.fit_transform(x)

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# Compare Models and Algorithms

# %%
models={'LinearRegression': LinearRegression() , 'RandomForestRegressor':RandomForestRegressor(),
        'AdaBoostRegressor':AdaBoostRegressor(), 'GradientBoostingRegressor':GradientBoostingRegressor(),
        'DecisionTreeRegressor':DecisionTreeRegressor(), 'KNeighborsRegressor':KNeighborsRegressor()
        }
results = []
names = []
for name,model in models.items():
    kfold = KFold(n_splits=10, shuffle=True, random_state=42)
    cv_results = cross_val_score(model, x_train, y_train, cv =kfold)
    print(model) 
    names.append(name)
    results.append(cv_results.mean())
# Out:
# LinearRegression()
# RandomForestRegressor()
# AdaBoostRegressor()
# GradientBoostingRegressor()
# DecisionTreeRegressor()
# KNeighborsRegressor()

# %%
plt.figure(figsize=((18,5)))
sns.barplot(names , results) 
plt.xlabel('name of models')
plt.ylabel('accuracy')
# Out:
# e:\anaconda install\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'accuracy')

# %% [markdown]
# 5. Model Tuning and Grid Search

# %%
'''
models={ 'RF':RandomForestRegressor(),'DT':DecisionTreeRegressor()}

RF_parm=  {'n_estimators':[50,100,200,300],'criterion':['absolute_error','squared_error'],'max_depth':[3,5,7]}
DT_parm = {'criterion':['absolute_error','squared_error'],'splitter':['random','best']}
params = {'RF':RF_parm,'DT':DT_parm}
results = []
names = []
max_score=0
max_model=None
max_model_params=[]

for name,model in models.items():
    gs = GridSearchCV(estimator=model,param_grid=params[name],cv=5)
    a = gs.fit(x_train,y_train)
    score = gs.score(x_test,y_test)

    if score > max_score:
        max_score = score
        max_model = gs.best_estimator_
        max_model_params = gs.best_params_
    
    names.append(name)
    results.append(score)
sns.barplot(names , results ) 
plt.xlabel('name of models')
plt.ylabel('accuracy')
'''
# Out:
# "\nmodels={ 'RF':RandomForestRegressor(),'DT':DecisionTreeRegressor()}\n\nRF_parm=  {'n_estimators':[50,100,200,300],'criterion':['absolute_error','squared_error'],'max_depth':[3,5,7]}\nDT_parm = {'criterion':['absolute_error','squared_error'],'splitter':['random','best']}\nparams = {'RF':RF_parm,'DT':DT_parm}\nresults = []\nnames = []\nmax_score=0\nmax_model=None\nmax_model_params=[]\n\nfor name,model in models.items():\n    gs = GridSearchCV(estimator=model,param_grid=params[name],cv=5)\n    a = gs.fit(x_train,y_train)\n    score = gs.score(x_test,y_test)\n\n    if score > max_score:\n        max_score = score\n        max_model = gs.best_estimator_\n        max_model_params = gs.best_params_\n    \n    names.append(name)\n    results.append(score)\nsns.barplot(names , results ) \nplt.xlabel('name of models')\nplt.ylabel('accuracy')\n"

# %%
#max_model

# %%
#max_model_params

# %%
model = DecisionTreeRegressor(criterion= 'absolute_error', splitter='random')
#model = RandomForestRegressor()
model.fit(x_train,y_train)
model.score(x_train,y_train)
# Out:
# 0.9949235645171458

# %%
model.score(x_test,y_test)
# Out:
# 0.9346988967873846

# %% [markdown]
# accuarcy using cross validation

# %%
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cv_scores = cross_val_score(model, x, y, cv=kf)
cv_scores.mean()
# Out:
# 0.9307432501715441

# %% [markdown]
# 6. confusion matrix

# %%
threshold_low = 33.3
threshold_high = 66.6

# Function to categorize values
def categorize(value):
    if value <= threshold_low:
        return 'Low'
    elif value > threshold_low and value <= threshold_high:
        return 'Medium'
    else:
        return 'High'
    
actual_output = y
predicted_output = model.predict(x)

actual_categories = np.array([categorize(value) for value in actual_output])
print (actual_categories)
predicted_categories = np.array([categorize(value) for value in predicted_output])
print (predicted_categories)
conf_matrix = confusion_matrix(actual_categories, predicted_categories, labels=['Low', 'Medium', 'High'])

print (conf_matrix)

sns.heatmap(conf_matrix, annot=True, cmap='Greens', fmt='g', xticklabels=['Low', 'Medium', 'High'], yticklabels=['Low', 'Medium', 'High'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
# Out:
# ['Low' 'Low' 'Low' ... 'Low' 'Low' 'Low']
# ['Low' 'Low' 'Low' ... 'Low' 'Low' 'Low']
# [[4374    1    2]
#  [   6  344    0]
#  [   1    0   82]]

# %%
count_low = np.count_nonzero(actual_categories == 'Low')
count_medium = np.count_nonzero(actual_categories == 'Medium')
count_high = np.count_nonzero(actual_categories == 'High')

print("Number of 'Low' instances:", count_low)
print("Number of 'Medium' instances:", count_medium)
print("Number of 'High' instances:", count_high)
# Out:
# Number of 'Low' instances: 4377
# Number of 'Medium' instances: 350
# Number of 'High' instances: 83

# %%
count_predicted_low = np.count_nonzero(predicted_categories == 'Low')
count_predicted_medium = np.count_nonzero(predicted_categories == 'Medium')
count_predicted_high = np.count_nonzero(predicted_categories == 'High')

print("Number of predicted 'Low' instances:", count_predicted_low)
print("Number of predicted 'Medium' instances:", count_predicted_medium)
print("Number of predicted 'High' instances:", count_predicted_high)
# Out:
# Number of predicted 'Low' instances: 4381
# Number of predicted 'Medium' instances: 345
# Number of predicted 'High' instances: 84

# %% [markdown]
# test model

# %%
df[df["risk_tol"]>70]
# Out:
#       age  education_level  married_state  no_of_kids  life_statge  \
# 409    39                2              2           0            1
# 410    39                2              2           0            1
# 1046   36                4              2           0            1
# 1127   36                4              1           0            2
# 1521   67                4              2           0            5
# ...   ...              ...            ...         ...          ...
# 4534   32                3              1           2            3
# 4535   32                3              1           2            3
# 4536   32                3              1           2            3
# 4537   32                3              1           2            3
# 4635   36                2              1           1            3
#
#       occupational_category        income  risk  eager   risk_tol
# 409                       1   4171.157196     4      0  74.102084
# 410                       1   4171.157196     4      0  71.537785
# 1046                      1  11448.495282     2      0  83.082413
# 1127                      1  12779.715663     3      0  79.715298
# 1521                      1   2573.692738     3      1  86.332880
# ...                     ...           ...   ...    ...        ...
# 4534                      1  11625.991332     2      0  74.298750
# 4535                      1  11625.991332     2      0  74.298750
# 4536                      1  11625.991332     2      0  74.298750
# 4537                      1  11625.991332     2      0  74.298750
# 4635                      2  12602.219612     2      0  80.346334
#
# [61 rows x 10 columns]

# %%
val = model.predict([[39,	2 	,2,	0,	1,	1	,4171.157196,	4	,0]])
val
# Out:
# e:\anaconda install\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([74.10208359])

# %%
categorize(val)
# Out:
# 'High'

# %%
val = model.predict([[47,	2,	1,	0,	2,	1,	4703.645348,	3, 0]])
val
# Out:
# e:\anaconda install\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# array([6.28685369])

# %%
categorize(val)
# Out:
# 'Low'

# %% [markdown]
# using joblib for deployment

# %%
joblib.dump(model,'risk_tolerance.joblib')
# Out:
# ['risk_tolerance.joblib']
